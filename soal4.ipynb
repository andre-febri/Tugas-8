# %%
from collections import deque

antrian_darurat = deque()
antrian_umum = deque()

n = int(input("Jumlah pasien: "))

for i in range(n):

    data = input(
        "Masukkan Nama dan Jenis (Umum/Darurat): "
    ).split()

    nama = data[0]
    jenis = data[1].lower()

    if jenis == "Darurat":
        antrian_darurat.append(nama)
    else:
        antrian_umum.append(nama)

pCirint ("\nurutan pelayanan:")

while antrian_darurat or antrian_umum:

    if antrian_darurat:
        print(antrian_darurat.popleft())
    if antrian_umum:
        print(antrian_umum.popleft())
# Out:
# Jumlah pasien: 5
# Masukkan Nama dan Jenis (Umum/Darurat): Andi Umum
# Masukkan Nama dan Jenis (Umum/Darurat): Budi Darurat
# Masukkan Nama dan Jenis (Umum/Darurat): Citra Umum
# Masukkan Nama dan Jenis (Umum/Darurat): Dewi Darurat
# Masukkan Nama dan Jenis (Umum/Darurat): Eka Umum
#
# urutan pelayanan:
# Andi
# Budi
# Citra
# Dewi
# Eka
